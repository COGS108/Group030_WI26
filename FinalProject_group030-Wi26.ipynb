# %% [markdown]
# # A Decade of Billboard Pop Hits: Factors That Influence Chart Success
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [ X ] NO - keep private
#
# ## Link to Video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
# In this data science research project, we investigated Pop songs in the Hot 100 Billboard Year-End Charts from 2015 to 2025 to observe whether factors such as song tempo (BPM), release seasons, and the presence of official YouTube music videos are correlated with song rank on these charts. By examining the influence of these variables on Pop song success, we aimed to understand how Billboard selects certain Pop songs over others when determining which ones to include on the Hot 100 charts. What unique features help one song stand out from the others? Are these features a long-term driving force or a temporary factor that declines with industry trends? Through a series of EDA techniques, including but not limited to bar plots, faceted scatter plots, and line plots, we uncovered whether having a faster tempo really mattered, if summer was truly the best time to release Pop hits, and finally, if official music videos were still an effective promotional strategy or simply a baseline standard for all Pop songs.
#
# Overall, our findings suggested that while song tempo, release season, and presence of official YouTube music videos show some association with ranking on the Billboard Hot 100 Year-End Charts, none of these factors alone strongly determines chart success. The analysis revealed that most successful Pop songs fall within a mid-to-upbeat tempo range (roughly 95 – 125 BPM), and Top 25 songs tend to have slightly higher tempos than lower-ranked songs, indicating a modest advantage for faster tracks (although this significance wasn't large in number). Contrary to our initial prediction, songs released in the summer did not dominate top chart positions and actually experienced an overall decline in median rank after their peak in 2022. Furthermore, seasonal differences were relatively small overall, with each experiencing fluctuations in rank over the decade; however, spring had the most consistent pattern, with median ranks between the Top 30 and Top 50. Additionally, because over 90% of songs in the dataset already had official music videos, video presence appeared to be a standard industry practice rather than a major differentiating factor in chart performance. Taken together, our EDA results indicated that while tempo, release timing, and music videos may contribute marginally to a Pop song’s success, Billboard chart rankings are likely influenced by a broader combination of factors.

# %% [markdown]
# ## Authors
# - Krisha Bhagat: Project Adminstration, Research Question and Hypothesis Development, Background research, Data curation/wrangling, Visualization, Writing - original draft/review & editing, Video (Speech)
# - Andrea Favian Cruz: Research Question and Hypothesis Development, Ethics and Privacy, Data curation/wrangling, Visualization, Writing - original draft, Video (Presentation)
# - Cindy Diaz: Research Question and Hypothesis Development, Data curation, Writing - original draft, Visualization, Video (Presentation)
# - Charlie Wang: Research Question and Hypothesis Development, Ethics and Privacy, Data curation, Writing - original draft, Visualization, Video (Speech)
# - Youjia Wang: Research Question and Hypothesis Development, Background research, Data curation, Writing - original draft, Visualization, Video (Presentation)

# %% [markdown]
# ## Research Question

# %% [markdown]
# How are official YouTube music videos, song tempo, and release seasons of Pop songs associated with achieving higher chart rankings in the Billboard Hot 100 Year-End Charts between 2015 and 2025? In this study, we will take a closer look at these top ranking songs’ calendar release dates, average BPMs, and whether they have official music videos to determine if these factors are correlated with their Billboard chart positions.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# What determines the ranking of Pop songs in renowned music lists like the Billboard Hot 100 Year-End Charts? Through our investigation, we hope to identify potential factors that may be associated with chart positions of these top songs. Can a song’s BPM indicate a higher ranking? What about the presence of an official music video? Is it more likely for a song to gain more popularity if it is released in the summer over the winter? By answering these questions, we aim to explore what characteristics drive chart placements of Pop songs, one of the largest and most diverse genres in the music industry.
#
# In past research conducted by Nunes and Ordanini (2014)<a name="cite_ref-1"></a><sup><a href="#cite_note-1">1</a></sup>, they examined how the type of instrumentation in a Pop song affects their success on music charts. Specifically, they analyzed data from the Billboard Hot 100 Weekly Charts spanning 55 years, comparing number-one singles with songs that never climbed above rank 90 to determine what factors made number-one hits. Using Qualitative Comparative Analysis and Quantitative Regression techniques, Nunes and Ordanini found that the presence of background vocals was a necessary component consistently seen in number-one ranking Pop songs. Furthermore, their results suggested that in the 1960s and late 2000s, songs with relatively few instruments ranked higher in the charts. On the other hand, songs with relatively many instruments ranked higher during the 1970s–1990s. They also proposed that the songs that ranked number one on music charts like the Billboard Hot 100 were typically unique, set apart from the current era of music trends. These findings indicate that specific musical features can play a critical role in chart performance, which informs our investigation into how additional factors like tempo, release season, and official music video presence may also be associated with higher Billboard rankings.
#
# In a similar study, Kim and Oh (2021)<a name="cite_ref-2"></a><sup><a href="#cite_note-2">2</a></sup> examined the relationship between certain audio features and a song’s success on the Billboard Hot 100 chart. They analyzed over 6,000 songs that appeared on the weekly charts between 1998 and 2016, and used regression analysis and predictive modeling to find patterns in the music that made a difference in chart performance. Their results showed that songs that felt more energetic and easy to dance to were more likely to reach the top 10. In particular, tracks with a steady and powerful beat often ranked higher on the charts. They also discovered that songs with a positive mood tended to perform better than those that sounded dark or melancholic. These uplifting songs seemed to connect more quickly with listeners and remain popular for longer periods of time. The study further indicated that timbre could also make an impact, as songs with clearer or more distinctive sounds were more likely to stand out and achieve higher chart rankings.
#
# Both studies above help shape how we think about our own research. Nunes and Ordanini focused more on musical structure, like how background vocals or instruments relate to chart success over time. Kim and Oh looked closely at how things like danceability and happiness affect chart performance. While these studies help show that the features inside a song matter, they don’t explore outside factors such as what time of year the song came out, or whether it has an official music video that may have increased its popularity. That’s where our project comes in. We’re combining factors including tempo, release season, and the presence of music videos to see how these things work together to influence a song’s ranking on the Billboard Hot 100 Year-End charts from 2015 to 2025. And in contrast to these previous studies, which focused on weekly charts and short-term song success, our study examines long-term chart success for Pop songs by analyzing Year-End charts instead.
#
# References:
# 1. <a name="cite_note-1"></a> <a href="#cite_ref-1">^</a> Nunes, J. C., & Ordanini, A. (2014). I like the way it sounds: The influence of instrumentation on a pop song’s place in the charts. *Musicae Scientiae*, 18(4), 392–409. [https://doi.org/10.1177/1029864914548528](https://doi.org/10.1177/1029864914548528)
# 2. <a name="cite_note-2"></a> <a href="#cite_ref-2">^</a> Kim, S. T., & Oh, J. H. (2021). Music intelligence: Granular data and prediction of top ten hit songs. *Decision Support Systems*, 145, 113535. [https://doi.org/10.1016/j.dss.2021.113535](https://doi.org/10.1016/j.dss.2021.113535)

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We predict that Pop songs with summer release dates, official YouTube music videos, and faster tempos are positively associated with higher Billboard yearly chart rankings from 2015 to 2025. Compared to those without videos, songs that have trending music videos may increase engagement and listening rates. Additionally, because summer is a socially active and highly favored season during which listeners often prefer upbeat, energetic music, Pop songs released during this period with faster tempos might gain more popularity, placing better ranks on lists such as the Billboard Hot 100 Year-End Charts.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data Overview
#
# **Dataset Name:** Billboard Hot 100 Year-End Singles (2015–2025)
# > This dataset will be our primary data that we will analyze to explore our research question for this project. We obtained this dataset through a series of intermediate steps. First, we decided to adopt a divide and conquer approach to minimize errors and maintain organization of the data. We split the data collection process among each member, making 5 individual CSV files that each contained a specific year range. For instance, the first CSV has data from 2015–2017, while the second has data from 2018–2019, etc. Since our research question involves examining genres, release seasons, song tempo, and music video presence, we had to use multiple sources to curate the data for each of these additional variables. This included Wikipedia for the Billboard charts, release dates and genre, YouTube for the official music videos, and finally SongBPM to identify the tempo for each song. In addition to this, we cross-referenced the information with other credible sources to ensure we were collecting accurate data. Each CSV was identically structured and built using the same collection techniques to prevent member bias and inconsistencies. After curating all 5 CSV files, we merged them into one master dataset, which we will use for the rest of the project duration.
#
# * **Link to the dataset:** [Master Dataset (Google Sheets)](https://docs.google.com/spreadsheets/d/13CpMHXhd6jVaWsLLfy1u--CaLFGUEoVZgCiG0Qv9hQA/edit?gid=0#gid=0)
# * **Number of observations:** 1,100
# * **Number of variables:** 8 (Rank, Title, Artist, Year, BPM, Genre, Release Date, Music Video)
# * **Most relevant variables:**
#
#     * **BPM:** Tracks a song’s tempo using beats per minute as a unit of measurement, defining the speed of the music (fast indicates a more energetic song while slow indicates a calmer song). In this project, a song having a tempo exceeding 120 BPM will be considered upbeat, high-energy music.
#     * **Genre:** Classifies songs based on overlapping musical characteristics (such as its instruments, rhythm, and mood). This dataset categorizes songs into the main umbrella categories of music, namely Pop, Hip-Hop, R&B, and Country as the dominant genres. This project will focus on charting songs that fall under the Pop genre.
#     * **Release Date:** Displays when a song was first released into the music industry. Since this project focuses on the season a song is released, we will convert these dates and categorize them based on whether they fall under spring, summer, fall, or winter.
#     * **Music Video:** Indicates whether a song has an associated official music video on YouTube (1 for Yes, 0 for No).
#
# - **Shortcomings:** Genres are a nuanced topic, where a song can be classified into numerous subcategories or contain mixtures of various genres. Therefore, our dataset is a more simplified version of the song’s characteristics, where we focus on categorizing the music based on the broader umbrella genres. Regarding release dates, due to some songs having newer versions or being re-released in more recent albums, the dataset displays the release date of the song depending on which version and from which album the song charted. For instance, if an older version of the song hit the charts compared to its updated one, we will list the release date of the older one. Similar to genres, music videos are also becoming more diverse and exclusive regarding what counts as a music video for a song. To simplify the data collection process for this project, we did not take into account lyric videos and mainly focused on the presence of more standard, traditional song music videos. Additionally, we referenced the actual video title to see if it explicitly includes the phrase “Music Video” to help us further determine whether we should count the song as having a music video or not.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
datafiles = [
    { 
      'url': 'https://docs.google.com/spreadsheets/d/13CpMHXhd6jVaWsLLfy1u--CaLFGUEoVZgCiG0Qv9hQA/export?format=csv', 
      'filename':'billboard_data_2015-2025.csv'
    }
]
get_data.get_raw(datafiles, destination_directory='data/00-raw/')
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Overall Download Progress: 100%|█████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.15s/it]
# Successfully downloaded: billboard_data_2015-2025.csv

# %% [markdown]
# ### Billboard Hot 100 Year-End Singles (2015-2025)
#
# This dataset contains over a decade-long collection of top songs from various genres (R&B, HipHop, Pop, & Country) that were featured on the Billboard Hot 100 Year-End Charts between 2015 and 2025. As mentioned earlier, we obtained our data from Wikipedia, SongBPM, and Youtube, since most of our metrics, such as genre, BPM, music video presence, and release date, could not be curated only by looking at the Billboard Year-End Charts.
#
# #### Most Relevant Metrics:
# - **Chart Rank:** A pre-established  value from 1 to 100. In this context, a lower numerical value indicates a higher rank (e.g. A song that charted number 1 is considered higher ranking than a song that charted number 10).
# - **BPM:** A beats per minute measurement that indicates the tempo of a song. To determine the tempo of Pop songs in particular, we will use the following ranges: a slow/calm, low-energy song is typically less than 100 BPM, a mid range tempo is 100–120 BPM, and a fast/upbeat, high-energy song has a tempo greater than 120 BPM.
# - **Genre:** A column that generalizes and categorizes each song from its numerous sub-genres into a primary umbrella music genre, such as R&B, Hip-Hop, Pop, or Country.
# - **Release Date:** Following the YYYY-MM-DD format, this column will help us classify the release season of each song in the dataset. Specifically, we will observe the "MM" portion of the date to determine whether the song was released in the winter (12, 01, 02), spring (03, 04, 05), summer (06, 07, 08), or fall (09, 10, 11).
# - **Music Video:** A binary representation (1/0) of the existence of an official YouTube music video, where 1 means Yes and 0 means No.

# %% [markdown]
# #### Major Concerns with the Dataset:
#
# **1. Genre Simplification and Classification**
# Although contemporary music spans a wide range of genres and subgenres, our analysis reduces this diversity into four broad categories: Pop, Hip-Hop, R&B, and Country. Each song was assigned to only one dominant category, even if it blended or was influenced by multiple stylistic elements. Subgenres were grouped under their broader parent genres (e.g., Trap under Hip-Hop), while genres less directly aligned with these four categories (e.g., Rock or Disco) were classified according to their closest stylistic or commercial association. In cases involving fusion genres or derivative forms (e.g., Trap-Pop, Dance-Pop), or when a song spanned multiple broad categories (e.g., both Pop and Hip-Hop), classification was guided by the song’s dominant commercial positioning within the Billboard context rather than strict music-theoretical distinctions. In particular, because Pop as a category often functions as a broad commercial umbrella for music that appeals to a general audience, songs with cross-genre characteristics were categorized based on their primary market identity within the Billboard chart ecosystem.
# While this coarse-grained classification improves analytical consistency and tractability, it also inevitably introduces subjectivity and collapses nuanced stylistic distinctions into broader categories.
#
# **2. Version Ambiguity in Release Date Identification**
# Many songs exist in multiple versions, including remixes, collaborations, re-releases, edited editions, cover versions, etc. We would always choose the charted version of the song as the focal observation: When the original version charted, we collected data from the original version; and when a specific remix or collaboration version charted, we collected data from that specific charting version. To ensure operational consistency and reproducibility, if multiple identical-content releases occurred (re-release of the exact same song), we selected the final release date prior to the song’s major rise in popularity to maintain temporal consistency with its chart performance. Despite these efforts, release dates may not perfectly correspond to the period during which a song accumulated the performance contributing to its Year-End ranking.
#
# **3. Strict Operational Definition of Official Music Videos**
# Again, to ensure operational consistency and reproducibility, only videos explicitly labeled as “Official Music Video” or “Official Video” on YouTube were coded as present. Lyric videos, studio performances, live recordings, leaks, cancelled releases, and unofficial uploads were excluded. While this strict operational definition reduces classification ambiguity, it may underestimate informal, unofficial digital virality, platform-driven exposure, or user-generated content that contributed to a song’s popularity (e.g., a viral TikTok video with the clip of a song causes the song to also go viral).
#
# **4. Reverse Causality Between Music Videos and Chart Rankings**
# A central limitation concerns potential reverse causality between music video production and chart performance. In some cases, music videos are produced and released after a song has already begun gaining traction, functioning as a strategic supplement or reinforcement of rising popularity. Under such circumstances, it becomes difficult to determine whether music videos drive chart success, or whether chart success motivates video production. Because this is an observational study using aggregated Year-End chart data, our findings should therefore be interpreted as associative rather than causal.
#
# **5. Tempo Measurement and Cross-Source Variability**
# BPM values were obtained primarily from SongBPM and cross-checked from Tunebat when necessary. However, minor discrepancies across databases or differences between song versions (e.g., radio edits, remixes, half-time or double-time interpretations, and there are even songs with almost exact same title, cover, released on close dates, but has different BPM) may introduce measurement error. Although efforts were made to match tempo values to the specific charting version (as stated in 2. Version Ambiguity in Release Date Identification above, the data is always selected from the specific charting version), BPM should be understood as an approximate musical indicator rather than a perfectly fixed structural constant.
#
# **6. Release Season and Popularity Timing Misalignment**
# In the streaming era, songs frequently reach their peak popularity after months—or even years—of their initial release. As a result, release season may not fully capture the timing of chart-relevant success. Our seasonal classification reflects the release timing, rather than the true period during which cumulative performance contributes to the Billboard Year-End ranking. This temporal misalignment limits the strength of our inferences regarding seasonal effects.
#
# **7. Seasonal Evergreen Songs and Recurring Chart Effects**
# Certain cultural/ holiday-themed “evergreen” songs reappear on Year-End charts due to cyclical cultural consumption patterns. For example, All I Want for Christmas Is You and Rockin Around the Christmas Tree both have appeared repeatedly since 2020 (5 times in our dataset). These recurring songs may inflate winter representation and reflect annual listening traditions rather than the classical release dynamics of contemporaneous songs. While such songs were retained as part of the Billboard system to reduce subjectivity of data selection, they may introduce structural seasonality effects independent of release timing.

# %% [markdown]
# #### Data Tidiness Justification
#
# We are loading the raw Billboard dataset from data/00-raw/. This dataset is already tidy because:
#
# - Each variable (Artist, Song, Genre, etc.) forms a column.
# - Each observation (a single song's chart entry) forms a row.
# - Each type of observational unit forms a table.
#
# Below, we have provided a missing data check to show that the dataset does not contain any null/blank values. Additionally, we also provided the size and display of the raw, uncleaned dataset to demonstrate its tidiness.

# %%
# Importing relevant files
import pandas as pd
import numpy as np

# Load data
df = pd.read_csv('data/00-raw/billboard_data_2015-2025.csv')

# Check for missing data
print("Missing Data Check: (all should be zero)")
print(df.isna().sum())
print()

# Display raw dataset
print ("Expect: Raw Dataset Shape: (1100, 8)")
print(f"Actual: Raw Dataset Shape: {df.shape}")
print()
display(df.head(10))
# Out:
# Missing Data Check: (all should be zero)
# Rank             0
# Title            0
# Artist           0
# Year             0
# BPM              0
# Genre            0
# Release Date     0
# Music Video      0
# dtype: int64
#
# Expect: Raw Dataset Shape: (1100, 8)
# Actual: Raw Dataset Shape: (1100, 8)
#    Rank              Title                         Artist  Year   BPM  \
# 0      1        Uptown Funk    Mark Ronson ft. Bruno Mars   2015  115
# 1      2  Thinking Out Loud                    Ed Sheeran   2015   79
# 2      3      See You Again  Wiz Khalifa ft. Charlie Puth   2015   80
# 3      4         Trap Queen                     Fetty Wap   2015  148
# 4      5              Sugar                      Maroon 5   2015  120
# 5      6    Shut Up & Dance                 Walk the Moon   2015  128
# 6      7        Blank Space                  Taylor Swift   2015   96
# 7      8           Watch Me                       Silentó   2015  140
# ...

# %% [markdown]
# #### Data Cleaning Process
#
#
# In the code below, we cleaned the dataset by removing any hidden spaces, filtering out non-Pop songs, replacing the Release Date column with the more relevant Release Season column, and finally resetting the index to ensure an organized structure.

# %%
# Remove hidden spaces from column names
df.columns = df.columns.str.strip()

# Remove hidden spaces from the Genre text itself
df['Genre'] = df['Genre'].str.strip()

# Filter out non-Pop genres, only keeping singles that fall under the Pop genre in the dataset
df_pop = df[df['Genre'].str.contains('Pop', case=False, na=False)].copy()

# Replace Release Date column with Release Season column, which shows if a Pop song was released in the winter, spring, summer, or fall
seasons = []
for date_string in df_pop['Release Date']:
    month = date_string[5:7]    
    if month == '12' or month == '01' or month == '02':
        seasons.append('Winter')
    elif month == '03' or month == '04' or month == '05':
        seasons.append('Spring')
    elif month == '06' or month == '07' or month == '08':
        seasons.append('Summer')
    else:
        seasons.append('Fall')

# Add the new column and drop the old one
df_pop['Release Season'] = seasons
df_pop = df_pop.drop(columns=['Release Date'])

#Reset index
df_pop = df_pop.reset_index(drop=True)

# Save the clean data
df_pop.to_csv('data/02-processed/billboard_data_pop_only.csv', index=False)

# %% [markdown]
# #### Data Cleanliness Justification
#
# Below, we added a visual display of the first 10 rows of the datset and added some test code to demonstrate that our dataset is properly wrangled and meets our data cleaning expectations.

# %%
# Verify the results
print("Expect: Unique Genres After Cleaning: ['Pop']")
print("Actual: Unique Genres After Cleaning:", df_pop['Genre'].unique())
print()
print("Expect: Total values of Release Season: 536")
print("Actual: Total values of Release Season:", df_pop['Release Season'].value_counts().sum())
print()
print("Expect: Unique Seasons After Cleaning: ['Fall', 'Spring', 'Winter', 'Summer']")
print("Actual: Unique Seasons After Cleaning:", df_pop['Release Season'].unique())
print()
# Display size of cleaned table
print("Expect: Cleaned Dataset Shape: (536, 8)")
print(f"Actual: Cleaned Dataset Shape: {df_pop.shape}")
print()
# Display cleaned table
display(df_pop.head(10))
# Out:
# Expect: Unique Genres After Cleaning: ['Pop']
# Actual: Unique Genres After Cleaning: <StringArray>
# ['Pop']
# Length: 1, dtype: str
#
# Expect: Total values of Release Season: 536
# Actual: Total values of Release Season: 536
#
# Expect: Unique Seasons After Cleaning: ['Fall', 'Spring', 'Winter', 'Summer']
# Actual: Unique Seasons After Cleaning: <StringArray>
# ['Fall', 'Spring', 'Winter', 'Summer']
# Length: 4, dtype: str
#
# Expect: Cleaned Dataset Shape: (536, 8)
# Actual: Cleaned Dataset Shape: (536, 8)
#    Rank                            Title                        Artist  Year  \
# 0     1                      Uptown Funk    Mark Ronson ft. Bruno Mars  2015
# 1     2                Thinking Out Loud                    Ed Sheeran  2015
# 2     3                    See You Again  Wiz Khalifa ft. Charlie Puth  2015
# 3     5                            Sugar                      Maroon 5  2015
# 4     6                  Shut Up & Dance                 Walk the Moon  2015
# ...

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis

# %%
# Importing relevant packages for visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Explicitly loading fully wrangled data
df_pop = pd.read_csv('data/02-processed/billboard_data_pop_only.csv')

# %% [markdown]
# #### 1. Univariate Exploration
#
# To establish a strong understanding of our data, we begin with a univariate analysis to identify the common characteristics of a typical Pop song found within the Billboard Top 100 charts. By analyzing the individual distributions of relevant factors such as BPM, track release times, and music video prevalence, we can pinpoint the standard behavior of the genre over the last decade. Incorporating these general visualizations allows us to identify commonalities across all successful Pop tracks, providing the necessary context to recognize outliers or unique shifts in later stages of our data analysis.

# %% [markdown]
# **PLOT 1: Number of Pop Song Releases in Different Seasons**
#
# This bar plot illustrates the number of Pop songs released in each season (Spring, Summer, Fall, and Winter). It helps to establish a basic understanding of the seasonal distribution of the Pop song releases in our dataset. This visualization provides a useful context in later analyses for evaluating our research question: "Pop songs with summer release dates are positively associated with higher Billboard yearly chart rankings from 2015 to 2025."

# %%
season_order = ["Spring", "Summer", "Fall", "Winter"]

season_counts = (
    df_pop["Release Season"]
    .value_counts()
    .reindex(season_order)
)

plt.figure(figsize=(10, 6))
ax = sns.barplot(x=season_counts.index, y=season_counts.values)

for i, v in enumerate(season_counts.values):
    ax.text(i, v, f"{int(v)}", ha="center", va="bottom")

plt.title("Number of Pop Song Releases in Different Seasons")
plt.xlabel("Release Season")
plt.ylabel("Number of Songs")
plt.tight_layout()
plt.show()

# %% [markdown]
# As shown in the above plot, the release season of the Pop songs are not evenly distributed. Among the total 536 Pop songs in our dataset, 159 Pop songs were released in Spring, 139 were released in Summer, 127 in the Fall, and finally, 111 Pop songs were released in the Winter. We could see a clear descending tendency of Spring release > Summer release > Fall release > Winter release, suggesting that artists may prefer to release Pop songs earlier in the year, particularly in Spring. Although this plot couldn't directly evaluate our hypothesis (positive correlation of Summer release and rank), it provides important context for later analyses. The uneven distribution of Pop songs across seasons suggests the sample size difference among the four seasons, which should be take into account in later comparisons between release season and chart ranking.

# %% [markdown]
# **PLOT 2: Distribution of Pop Song Tempo (BPM)**
#
# This histogram with a KDE curve shows the overall distribution of Pop song tempos (BPM) in our dataset. The goal is to examine the general pattern of Pop music tempo and see whether songs tend to cluster within a specific BPM range or spread widely across slower and faster tempos. Understanding this distribution provides a baseline for later analyses of whether tempo might be related to chart performance.

# %%
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

sns.histplot(data=df_pop, x='BPM', bins=20, kde=True)

plt.title('Distribution of Pop Song Tempo (BPM)', fontsize=15, pad=15)
plt.xlabel('Beats Per Minute (BPM)')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# From the histogram, most Pop songs cluster within a mid-to-upbeat tempo range, with the highest concentration roughly between 95 and 125 BPM. This suggests that many songs in the Billboard Year-End charts follow a similar tempo range rather than being evenly distributed across all BPM values. There are fewer songs with very slow tempos (below about 80–90 BPM), indicating that slower songs appear less frequently in this dataset. The distribution also shows a right-skewed tail, where a smaller number of songs reach very fast tempos above 150 BPM, extending close to 200 BPM. These higher-tempo songs appear much less common compared to the main cluster. Overall, the plot suggests that successful Pop songs tend to follow a relatively consistent tempo range, while extremely slow or extremely fast tempos are less common.

# %% [markdown]
# **PLOT 3: Number of Pop Songs With/Without Official Music Videos**
#
# This simple bar plot illustrates the number of Pop songs that have or don't have an official music video. It provides an intuitive visualization of this binary variable in our dataset, helping to later investigate our research question: "Pop songs with official music videos are positively associated with higher Billboard yearly chart rankings from 2015 to 2025." In our dataset, the presence of a music video is represented as a binary variable (1 = Yes, 0 = No), which is mapped to the labels “Yes” and “No” in this plot for clearer visualization.

# %%
mv_labels = df_pop["Music Video"].map({1: "Yes", 0: "No"})

mv_counts = mv_labels.value_counts().reindex(["Yes", "No"])

plt.figure(figsize=(10,6))
ax = sns.barplot(x=mv_counts.index, y=mv_counts.values)

for i, v in enumerate(mv_counts.values):
    ax.text(i, v, f"{int(v)}", ha="center", va="bottom")

plt.title("Songs With/ Without Official Music Videos")
plt.xlabel("Official Music Video Exsistance")
plt.ylabel("Number of Songs")
plt.tight_layout()
plt.show()

# %% [markdown]
# According to the bar plot above, there seems to be a strong imbalance regarding the existence of official music videos in Pop songs. Among the total 536 Pop songs in our dataset, 516 Pop songs (~ 96%) have at least one official music video, while a dramatically low number of 20 Pop songs (~ 4%) do not have one. This huge difference in percentage suggests that official music videos are extremely common among majority of commercially successful Pop songs (within our dataset). Since the number of songs without music videos is very small, comparisons between songs with and without music videos may be less reliable, especially given that we did not consider the reverse causality of official music videos and popularity (see "Major Concerns with the Dataset: 4. Reverse Causality Between Music Videos and Chart Rankings" section above). Therefore, such comparisons and analyses (e.g. the existence of official music videos vs. rank) should be interpreted cautiously.

# %% [markdown]
# #### 2. Conducting Bivariate Analyses
#
# While understanding individual characteristics is helpful, our primary research question requires a more direct investigation into the relationship between our factors of study and song ranks. Therefore, this section focuses on delving into bivariate examinations, where we specifically observe how BPM, release season, and music video presence associates with a song's Billboard rank. By comparing these three factors with pre-established rank tiers, we aim to discover whether things like higher BPM or summer release dates show a significant correlation with better chart placement (within the Top 25), moving us closer to uncovering our research question of what truly drives a Pop song's success in the Billboard charts.

# %% [markdown]
# **PLOT 4: Distribution of Top 25 Hits Across Release Seasons**
#
# This 100% stacked bar plot looks at how the share of the Top 25 hits change across seasons. By splitting songs into two groups, Top 25 and 26-100, we can see if certain times of the year tend to produce more high performing tracks. The goal here is to find out if releasing timing plays a role in chart success or if Pop hits perform about the same no matter when they come out.

# %%
df_pop.loc[:, 'Rank Tier'] = pd.cut(df_pop['Rank'], 
                                    bins=[0, 25, 100], 
                                    labels=['Top 25', '26-100'])


contingency_table = pd.crosstab(df_pop['Release Season'], df_pop['Rank Tier'])

percent_table = contingency_table.div(contingency_table.sum(axis=1), axis=0) * 100

season_order = ['Spring', 'Summer', 'Fall', 'Winter']
percent_table = percent_table.reindex([s for s in season_order if s in percent_table.index])

ax = percent_table.plot(kind='bar', 
                        stacked=True, 
                        figsize=(10, 6), 
                        color=['#0096FF', '#D3D3D3'],
                        edgecolor='white')

plt.title('Percentage of Top 25 Hits by Release Season', fontsize=15, pad=20)
plt.ylabel('Percentage (%)')
plt.xlabel('Season')
plt.xticks(rotation=0)
plt.legend(title='Rank Tier', bbox_to_anchor=(1.05, 1), loc='upper left')

for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    if height > 0:
        ax.text(x + width/2, 
                y + height/2, 
                f'{height:.1f}%', 
                ha='center', va='center', 
                color='white' if y < 50 else 'black', 
                fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# Looking at the results above, Fall holds the highest portion of Top 25 Pop hits at 34.6%, followed closely by Winter with 33.3%. This suggests that songs released during the colder months may perfrom slightly better on average in terms of chart placement. Spring, with 30.8%, maintains a moderate share of Top 25 tracks, while Summer shows the lowest proportion at 25.2%. Indicating that summer releases, despite being commonly associated with "hit" potential, may not always translate into top-tier chart success. Overall, these results imply that timing release might influence chart performance, but not in the way one might expect. Instead of Summer dominating the Pop charts, the data hints that Fall and Winter could be more favorable periods for higher-ranking songs. However, the differences across seasons are relatively small, suggesting that seasonality may play a minor role compared to other factors that drive a song's success.

# %% [markdown]
# **PLOT 5: BPM Differences Between Top and Bottom 25 Pop Songs**
#
# This box plot compares the BPM distributions for Pop songs in the Top 25 versus the Bottom 25 chart positions. By focusing on the extremes, we can see whether higher-ranking songs tend to have faster tempos on average, helping us explore whether tempo might be linked to chart success within the Pop genre.

# %%
df_extremes = df_pop.copy()

def get_extreme_tier(rank):
    if rank <= 25:
        return 'Top 25'
    elif rank >= 75:
        return 'Bottom 25'
    return None

df_extremes['Extreme Tier'] = df_extremes['Rank'].apply(get_extreme_tier)
df_plot = df_extremes.dropna(subset=['Extreme Tier'])

plt.figure(figsize=(8, 6))
sns.set_style("whitegrid")


ax = sns.boxplot(data=df_plot, 
                 x='Extreme Tier', 
                 y='BPM', 
                 hue='Extreme Tier',
                 order=['Top 25', 'Bottom 25'],
                 palette=['#6A0DAD', '#D3D3D3'], 
                 showmeans=True, 
                 meanprops={"marker":"d", "markerfacecolor":"white", "markeredgecolor":"black"},
                 legend=False)     

plt.title('BPM Distribution: Top 25 vs. Bottom 25', fontsize=15, pad=20)
plt.ylabel('Beats Per Minute (BPM)', fontsize=12)
plt.xlabel('Rank Tier', fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# Looking at the box plot, Top 25 songs tend to have a slightly higher tempo, with BPMs ranging from around 100 to 137. In contrast, the Bottom 25 songs have a slightly lower BPM distribution starting around 97 and going up to 130. This suggests that faster-paced songs may have a modest advantage in reaching the top of the charts but the overlap in BPM ranges shows that tempo alone isn't a deciding factor. Some slower songs still break into the Top 25 and some faster songs remain in the Bottom 25. Overall, while higher BPM might give songs a slight edge, chart success is clearly influenced by multiple factors beyond just tempo.

# %% [markdown]
# **PLOT 6: Percentage of Official Music Video Presence in Top 25, Middle 50, and Bottom 25 Songs**
#
# This bar plot compares the percentage of songs with an official music video across three chart position groups: Top 25, Middle 50, and Bottom 25. The goal is to test whether higher-ranking songs have a higher density of official music videos than lower-ranking songs. This helps us explore whether the presence of an official YouTube music video may be associated with better chart performance.

# %%
df_mv = df_pop.copy()

def rank_tier(rank):
    if 1 <= rank <= 25:
        return 'Top 25'
    elif 26 <= rank <= 75:
        return 'Middle 50'
    else:
        return 'Bottom 25'

df_mv['Rank Tier'] = df_mv['Rank'].apply(rank_tier)

mv_percent = df_mv.groupby('Rank Tier')['Music Video'].mean() * 100
mv_percent = mv_percent.reindex(['Top 25', 'Middle 50', 'Bottom 25'])

plt.figure(figsize=(9, 6))
sns.set_style("whitegrid")

ax = sns.barplot(x=mv_percent.index, y=mv_percent.values)

plt.title('Percentage of Songs with an Official Music Video by Rank Tier', fontsize=15, pad=15)
plt.xlabel('Rank Tier')
plt.ylabel('Percentage (%)')
plt.ylim(0, 110)

for i, val in enumerate(mv_percent.values):
    ax.text(i, val + 1, f'{val:.1f}%', ha='center', va='bottom', fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# Based on the graph, official music videos are extremely common in every rank group, but the Top 25 has the highest percentage. Specifically, about 99.4% of Top 25 songs have an official music video, compared to 95.8% in the Middle 50 and 92.6% in the Bottom 25. This pattern supports the idea that higher-ranking songs are slightly more likely to have official music videos, but the difference between groups is relatively small. Since even the Bottom 25 still has over 90% of songs with music videos, having an official music video appears to be very common among Billboard Year-End Pop songs overall. Therefore, while there may be a small positive relationship between music video presence and higher chart rank, music videos alone likely do not fully explain chart success. Other factors, such as tempo or release timing, may also contribute to differences in chart performance.

# %% [markdown]
# #### 3. Observing Multivariate Interactions

# %% [markdown]
# **PLOT 7: Correlation Between Tempo (BPM) and Chart Success Across Release Seasons**
#
#
# The following visualization is a faceted scatter plot comparing how 'Release Season' can influence the interactions between the 'BPM' and Billboard Chart 'Rank' of Pop songs. By implementing this multivariate approach in our analysis, we will test our hypothesis that higher BPMs have a stronger influence on a song's ability to reach top-tier chart positions (1-25) when the song is released in the summer compared to other seasons.

# %%
interactions = sns.lmplot(data = df_pop, x = 'BPM', y = 'Rank', col = 'Release Season', hue = 'Release Season')

# Inverting y-axis so Rank 1 is at top and Rank 100 is at bottom
for ax in interactions.axes.flat:
    ax.set_ylim(105, 0)
    ax.set_yticks(np.arange(0, 110, 10))

    #highlights the Top 25 song ranks
    ax.axhline(25, ls='--', color='purple', alpha=0.7)

plt.suptitle('Correlation Between BPM and Song Rank By Release Season', fontsize=16)
plt.subplots_adjust(top=0.85)
plt.show()

# %% [markdown]
# Looking at the results above, the summer chart exhibits the most noticeable positive slope, indicating that higher BPM may subtly increase the chances of a Pop song reaching higher ranks. In contrast, the winter releases chart shows a slightly downward slope and contains fewer song distributions past the 120 BPM mark, implying that a higher tempo might actually decrease a song's chances of ranking in the top-tier positions during colder months. Finally, fall and spring are both nearly horizontal slopes, suggesting that BPM may have little to no influence on song rank during these seasons. However, it is important to note the significant variability in the scatter plots along with the fact that none of the regression lines bypass the Top 25 threshold. This finding illustrates that although summer releases have the strongest positive pull regarding tempo influence on rank, BPM is more of a supporting factor than a sole determinant of success for Pop songs. These results align with the idea that Pop song success is a complex concept, with many collective factors apart from tempo that can influence a song's performance in elite charts like the Billboard Hot 100.

# %% [markdown]
# #### 4. Exploring Evolution of Pop Trends
#
# Since our question revolves around understanding Pop success in Billboard Charts from the last decade, it is important to consider emerging trends and patterns in BPM, release seasons, and music videos of charting songs from this genre. Therefore, the following lineplots will serve as intuitive visualizations that support our research in determining whether the effectiveness of our factors of study has changed from 2015 to 2025 in influencing Pop song chart performance.

# %% [markdown]
# **PLOT 8: Median BPM Trends in Pop Music from 2015-2025**
#
# This line plot explores the temporal evolution of song tempo within the Pop genre from 2015 to 2025. By using the median as our estimator, we can effectively visualize the 'average' pace of a modern Pop song without the data being skewed by outliers, such as extremely slow or extremely fast tracks. This analysis aims to determine if high-charting Pop music has physically sped up throughout the decade or if the Pop industry has maintained a consistent BPM standard.

# %%
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")

line_plot = sns.lineplot(
    data=df_pop, 
    x='Year', 
    y='BPM', 
    estimator='median',  
    errorbar=None, 
    marker='o', 
    color='#ff4d4d', 
    linewidth=2.5
)

plt.title('Median BPM of Pop Songs (Billboard Top 100: 2015-2025)', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Median BPM', fontsize=12)
plt.xticks(range(2015, 2026))

plt.show()

# %% [markdown]
# The line plot above reveals a distinct 'V' shape in tempo trends over the decade. Between 2015 and 2017, there was a sharp drop in median BPM, reflecting a period where slower-paced, minimalist Pop tracks dominated the charts. However, starting in 2019 and continuing through 2023, the tempo increased significantly, with Pop music consistently hovering between 113–118 BPM. While there is a slight dip from the 2024 peak, the data for 2025 indicates a prevailing interest in upbeat, high-energy Pop songs compared to the beginning of the decade. This finding suggests a shift in listener preference toward faster tempos as the decade progressed, potentially indicating that higher song BPMs may, in fact, positively influence which songs place the Billboard charts.

# %% [markdown]
# **PLOT 9: Offical Music Video Presence over the Decade (2015-2025)**
#
# The following bar plot examines the percentage of top Pop songs with an official music video per year to observe changes in how they are used as a method for gaining song popularity. Specifically, we are analyzing whether music videos are becoming more or less common in the streaming era, or if they have maintained a consistent presence. This will help us determine if music videos have a prevalent or no effect on chart rankings.

# %%
video_trend = df_pop.groupby('Year')['Music Video'].mean() * 100

plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")

sns.barplot(
    x=video_trend.index, 
    y=video_trend.values, 
    color="#0096FF"
)

for i, val in enumerate(video_trend.values):
    plt.text(i, val + 1, f'{val:.1f}%', ha='center', va='bottom', fontweight='bold')

plt.title('Percentage of Pop Hits with an Official Music Video (2015-2025)', fontsize=14, pad=15)
plt.ylabel('Percentage (%)', fontsize=12)
plt.xlabel('Year', fontsize=12)
plt.ylim(0, 110)

plt.tight_layout()
plt.show()

# %% [markdown]
# Based on the graph above, the majority of Pop songs maintained an official music video presence throughout the decade, consistently remaining within the 90–100% range for each given year. The years 2018–2021 show a perfect 100% streak, illustrating that all Pop songs during those years were accompanied by music videos upon their release. Starting from 2022 onwards, there is a slight dip in music video presence. However, this change is not large enough to be considered significant, as the percentage still remains above 90%. This dominating pattern indicates that music videos may simply be a standard characteristic of the Pop genre rather than an influential factor that drives song charting performance.

# %% [markdown]
# **PLOT 10: Evolution of Median Pop Song Rank By Release Season from 2015-2025**
#
# This line plot tracks the charting performance of Pop songs over the last decade, categorized by their release season. By plotting the median rank for each year, we can identify long-term shifts in seasonal dominance and determine the validity of our hypothesis: whether summer releases truly are a consistent industry trend related with better chart success or simply a year-dependent, fluctuating factor.

# %%
plt.figure(figsize = (14, 7))
sns.lineplot(data = df_pop, x = 'Year', y = 'Rank', hue = 'Release Season', hue_order = ['Winter', 'Spring', 'Summer', 'Fall'], marker = 'o', estimator='median', errorbar = None)

# Inverting y-axis so Rank 1 is at top and Rank 100 is at bottom
plt.gca().invert_yaxis() 

# Forcing plot to show all 11 years
plt.xticks(df_pop['Year'].unique(), rotation = 45)

plt.title('Seasonal Trajectory of Median Pop Song Rank (2015-2025)', fontsize = 16)
plt.ylabel('Median Rank', fontsize = 12)
plt.xlabel('Year', fontsize = 12)
plt.grid(True, linestyle = '--', alpha = 0.5)
plt.legend(title = 'Season', bbox_to_anchor = (1.05, 1), loc = 'upper left')

plt.show()

# %% [markdown]
# Before jumping into seasonal specifics, a relevant finding from this visualization regarding the Pop genre as a whole is that both 2016 and 2020 have median ranks successfully passing the top 20 position, suggesting that the Pop genre achieved the most success in Billboard chartings during those two years out of the entire decade. Moving onto observing the individual seasonal trends, the lineplot above illustrates that spring releases suprisingly have the most consistent trend, ranging a steady 30-50 median charting position over the years. Pop songs released in the winter, on the other hand, seem to be facing a gradual decline over the years (with the exception of some peak times, including 2016 and 2020). Its overall pattern indicates a drop from the top-tier ranks to the lower-middle ranks (45-70), especially after 2020. Fall releases had the most chart success in the years between 2018-2021, consistently placing a median Billboard rank within the top 40, but drastically dropped to the lower 70s during 2022 and remained in the bottom ranks there-after. One particularly interesting observation is that the summer Pop releases showed the most success during the years that the winter and fall releases were showing a sharp decline (2021-2022). However, considering the overall trends between all the seasons, Pop songs released in the summer fall mostly in the middle-tier range of 40-65, with the exception of its short peak in performance a little after the emergence of COVID-19. This insightful result indicates that summer releases may not have as strong of an influence on Billboard chart success as we initially assumed it to, pointing to the idea that some factors may only have short-term impacts on musical performance over the years.

# %% [markdown]
# ## Ethics
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# > This project will not involve human subjects or user-level data. All data is collected from publicly available sources at the song or chart level, including Billboard Year-End Hot 100 rankings, Spotify audio features, and the presence of official YouTube music videos. Thus, informed consent from individuals is not applicable for our project.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# > As mentioned above, the ideal data sets that we can use are Billboard End Year Hot 100 rankings, Spotify Audio Features (BPM), and Youtube (music videos). However, it only reflects commercially successful songs, which would be strongly affected by industry promotion, platform algorithms, and chart methodologies, etc. As a result, our findings are limited to only the commercially successful Pop songs. It cannot be generalized to all music.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# > We are only using general, publicly available information at the song or artist level. We are not going to collect or analyze any personal/user-level data, ensuring all data is organized and anonymous, minimizing privacy-related risks.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# > As mentioned above in A.2, Our findings may reflect biases associated with commercial success and platform exposure, rather than the true inherent musical quality. If these biased findings were interpreted normatively, it might reinforce the existing industry advantage of the famous artists/ platforms with sufficient resources. To mitigate this, we will limit our conclusions strictly to commercially successful Pop songs, avoid any prescriptive or causal claims, and clearly stating the structural limitations of our dataset.
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
# > Even though the information and data used in this project are from public platforms such as Billboard, Spotify, and YouTube, each website has rules and regulations about how their data can be used. So, we need to follow their terms of use by using these data for academic purposes only, and not share or sell the data.
#
#  - [ ] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# > Yes, the data will only be used for academic purposes in this project, and it will be deleted right after this project ends (end of the UCSD 2026 Winter Quarter).
#
# ### C. Analysis
#  - [ ] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# > The dataset we chose (online platforms) may favor certain artists, genres, or countries based on their promotion algorithms. These platform-specific biases may influence chart rankings and confound our conclusion of the relationships between the musical features (summer release dates, official YouTube music videos, and faster tempos) and success. Unfortunately, we can’t eliminate these biases (since ‘popular’ basically equals ‘commercially successful’), but we mitigate their impact by stating clearly that our analyzing result is limited strictly to commercially successful Pop songs and cannot be generalized to all music.
#
#  - [ ] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#  - [ ] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# > All of our data sources, processing steps, and analytical methods will be documented to support reproducibility and transparency.
#
# ### D. Modeling
#  - [ ] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  - [ ] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - [ ] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  - [ ] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# > As mentioned above in the C.2 part, We will clearly state the limitations of our project and our chosen dataset, including the influence of marketing budgets, exposure, and platform algorithms that are not directly measurable.
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#
# > Our project will not deploy a model or system in the real world, therefore, continuous monitoring is not applicable for this project.
#
#  - [ ] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [ ] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# > There is a risk that findings may be misinterpreted as a prescriptive guidance for producing “success music”. Again, we would mitigate this by clearly stating that our conclusions are limited strictly to commercially successful Pop songs only, and framing our conclusions as descriptive and exploratory language, rather than normative language.

# %% [markdown]
# ## Discussion and Conclusion
#
# ### Summary of Results and Their Connection to Prior Work
# The time has come to curate our top findings from our EDA, where we will explore the emerging patterns and numbers depicted by our visualizations. These insights build the foundation for understanding the dynamics at play in Pop chart performance.
#
# First, diving into our release season plots, we observed that Pop songs were not released evenly across the year. Spring had the most songs in our dataset (159), followed by summer (139), fall (127), and finally winter, which had the fewest (111). When we compared seasons by chart performance, however, the pattern was not as simple as saturated songs performing better. In fact, fall and winter had slightly larger shares of Top 25 songs (34.6% and 33.3%), while spring and summer had the lowest percentage of Top 25 Hits (30.8% and 25.2%), despite these seasons having the highest distribution of Pop songs. The seasonal trend over time also changed dramatically from year to year: Spring was the most stable, with a median rank of 30-50. Winter peaked in 2016, then experienced an overall decline in median rank. Fall releases peaked in 2020, but their rank ultimately decreased in the following years. Finally, summer did quite well for the majority of the decade, peaking in 2022 with a median rank in the Top 20, but then had a sharp downward trend thereafter.
#
# Regarding BPM, most songs were grouped in a similar mid-to-upbeat range of 95-125 BPM. The Top 25 songs had slightly higher tempos, ranging from 100 to 137 BPM, while the Bottom 25 songs ranged from 97 to 130 BPM; but the two groups' range largely overlapped. These numbers suggest that faster songs may have a slight advantage, although not significant.
#
# Discussing our last factor of study, the presence of official music videos was largely prominent for almost every Pop song, with a whopping 96% of our dataset having a music video. Differentiating by rank, 99.4% of the Top 25 songs, 95.8% of the Middle 50, and 92.6% of songs in the Bottom 25 all had associated YouTube videos. Even if we dissected these percentages by year, the numbers were above 90% each year, implying that music videos are almost always an included feature in Pop songs.
#
# Our results also connect back to the studies we discussed earlier in our Background section. Nunes and Ordanini (2014) showed that musical features can affect chart success, while Kim and Oh (2021) found that more energetic songs often perform better. Our findings partly support their earlier work, especially since BPM showed a weak positive pattern with charting success. Aside from observing musical qualities of songs, our project expands on this prior work by also examining external factors such as release season and music video presence. Additionally, we referenced data from the Billboard Year-End charts from 2015 to 2025, a source that provides us with a longer-term view of success compared to these prior studies, which focused on weekly chart performance.
#
# Overall, our findings suggest that Pop chart success is more complex than we first expected. In the following sections, we will explain how these results inform our research question and potentially support (or invalidate) our original hypothesis regarding the association between Billboard chart rank and our three factors of study.
#
# ### Are Summer Pop Releases Really the Most Successful on Billboard Charts?
# Now, it is time to connect our summarized results to validate our initial hypothesis: Pop songs with summer release dates, official YouTube music videos, and faster tempos are positively associated with higher Billboard yearly chart rankings from 2015 to 2025. Starting with an evaluation of the potential influence of our release season factor on chart rankings, we originally predicted that Pop songs released in the summer performed better on Billboard Year-End charts due to their often energetic and upbeat qualities. Weaving the results together led us to infer that our hypothesis was partially correct, with some contradictory and quite surprising findings. Behind spring, summer had the second-highest number of Pop songs in the dataset, and it also had a gradual upward trend in median rank for the majority of the decade, peaking into the Top 20 tier during 2022. When comparing the correlation between BPM and rank by season, we found that summer had the most positive slope, supporting our prediction that Pop songs with summer release dates and higher tempos are likely to have better Billboard chart status. In contrast, summer’s opposing season, winter, not only showed an overall decline in median rank over the years, but its correlation between BPM and song rank also had a slightly negative slope. These contrasting results depict that calmer, slower songs (which are often characteristic of the winter season) do not perform as well in charts.
#
# So far, our findings strongly support our initial hypothesis that the summer season is a prominent driving factor positively associated with Billboard charting success of Pop songs. However, we noticed that its influence might be weakening, as after its peak in 2022, summer Pop releases experienced a sharp decline in median rank and remained in the Bottom 50 from that point forward. Furthermore, although the summer season had the second-highest number of songs in the dataset, it had the lowest number of Top 25 hits from the whole decade combined. This quite unusual finding contradicts the assumption that songs of higher volume often have higher performance rates, leading us to conclude that although summer releases have a strong presence overall in the charts, they aren’t always top-ranking.
#
# Finally, we would like to conclude this section by presenting a hidden variable that may have the potential to increase Pop song charting success: spring release dates. Compared to the summer, the spring season had the most consistent trend in median rank throughout the decade. Songs in that category consistently ranked in the Top 50, never dropping into the lower tiers. Additionally, it surpassed summer and had the highest number of Pop song releases of the decade. These results support our new inference that the spring season may be positively associated with achieving better Pop song rankings on the Billboard charts. However, we also think that since spring comes before summer, it potentially ‘sets the stage’ for the incoming, high-energy season. Therefore, many Pop artists may be releasing their summer hits earlier in the spring season as a promotional strategy, which may be why we are seeing such prominent results from this category. Overall, we conclude that the summer season did, at one point, have an effective influence on Pop song chart success, but it wasn’t a long-term driving force, especially near the end of the decade.
#
# ### MV presence in Pop Songs: Does it Really Matter?
# Moving to our next inquiry, we examined whether official music videos on YouTube still hold relevance as a promotional tool that increases a Pop song’s chart success. Despite our prior assumptions, we found that music videos may not be a big contributing factor in elevating Billboard rankings of Pop songs. From 2015 to 2025, we noticed that music videos were a strong and consistently present feature in almost all of the Pop songs in our dataset. These high yet stagnant percentages indicate the lack of a correlating trend, suggesting that music videos are more of a barrier to entry than an influential advantage for Pop songs. Furthermore, music videos were a prominent factor in every song, regardless of its charting status, implying that they are not a unique variable exclusively shared by the Top 25, as even the Middle 50 and Bottom 25 have them. These consistent findings demonstrate that, although this factor has a strong presence overall, music videos may simply be a typical, baseline trait shared among all Pop songs, not a driving force that improves a song’s probability of chart success. Therefore, we conclude that music videos are not a promotional factor that increases rank status; instead, we suggest that these visual assets are more of a standardized feature in Pop music.
#
# ### Does Higher BPM actually Lead to Higher Chart Positions?
# Finally, we determined whether Pop songs with faster tempos are positively correlated with higher Billboard Year-End Chart rankings. After analyzing our findings, we found that Pop songs tend to remain in the ‘sweet spot’ for tempo range, where they are not too slow, but also aren’t overwhelmingly fast. To start, we noticed a right-skewed distribution of BPM in our dataset, with the majority of its concentration being between 95 and 125. We found similar results when observing the correlation between BPM and the rank of Pop songs based on seasonal release, where the cluster of songs for almost every season (especially spring) remained in this sweet spot. This suggests that a higher tempo does not mean better chart performance, but that a song needs to remain in the middle ground of BPM to be more successful. Even when observing the distribution of BPM between the Top 25 and Bottom 25 tiers, the songs remained in this range, indicating that neither group has songs that are overtly fast. However, we noticed that the Top 25 had a slightly higher tempo range (100-137) than the Bottom 25 (97-130), but the overlap between the two groups is significantly large, revealing that BPM cannot independently drive chart success and may need the presence of other factors to have a true effect. Overall, our prior assumption that faster tempo songs have better Billboard positions than those with slower tempos was false, as Pop songs remained in the middle ground for BPM regardless of their rank status, again indicating that BPM alone does not have a strong correlation with higher Billboard chart positions.
#
# ### Research Limitations
# 1. Our dataset only includes the songs that appeared on the Billboard Year-End Hot 100 Singles Charts between 2015 and 2025. That is to say, our dataset represents those songs that are already “successful”, rather than the broader population of all Pop releases. Such sampling structure makes it difficult to determine whether certain factors actually contribute to chart success, or simply reflect some common characteristics among the popular, mainstream songs (such as the existence of official music videos).
#
# 2. We did not largely consider possible changes in the music industry over the 11 year span our research investigated. Over those years, the growing influence of streaming platforms, algorithmic playlists, and short-form content may have significantly affected how songs gain popularity and how long they remain visible in the charts. For example, listening to 'All I Want for Christmas Is You' and 'Rockin’ Around the Christmas Tree' during Christmas seems to become an increasingly popular “tradition” after 2020. The dynamic, constantly changing listener preferences and trending cultures may help explain why certain patterns in our analysis, such as the influence of summer releases, appear to weaken in later years.
#
#
# 3. Several variable-specific limitations should also be acknowledged. BPM values may vary slightly depending on the measurement source or version of a song, which may introduce minor inconsistencies in tempo comparisons. In addition, the strong imbalance in music video presence within our dataset — combined with the possibility of reverse causality, where already popular songs are more likely to receive official music videos — makes it difficult to isolate the independent effect of music videos on chart performance. Seasonal chart patterns may also be influenced by recurring cultural phenomena, such as evergreen holiday songs, which can affect the apparent performance of certain seasons.
#
# ### Next Steps
# Some possible directions for future research would be to address the current limitations of this investigation and expand its scope. First, we could include a broader dataset that captures a wider range of Pop songs, including those that did not reach major chart success. This is because, by comparing the “successful and popular” songs with those “less successful, less popular” ones, we could better evaluate the actual effectiveness of our three factors (release season, BPM, and official music video presence) on chart-success and song popularity. Second, we could also explore how the effectiveness of these factors changed over time. A more explicit, longitudinal analysis could help us determine whether the relationships between release season, BPM, and chart rankings have changed across different phases of the streaming era. For example, comparing earlier years of the dataset with more recent periods influenced by viral social media platforms may reveal the shifting patterns of the music industry. Finally, incorporating additional variables could provide us with a more comprehensive understanding of Pop songs’ chart performance. Factors such as streaming counts, playlist placement, artist popularity, and social media engagement may play significant roles in determining a Pop song’s commercial success. Furthermore, we could investigate how different factors interact with one another. For example, how does social media engagement and the existence of official music video jointly influence chart rank? Including these variables in future analyses could help us build more robust models of how musical characteristics and promotional strategies interact to shape Billboard chart outcomes.

# %% [markdown]
# # Thank You for Reading!
